-- %%
USE CATALOG fashion_catalog;
USE SCHEMA fashion_synthetic_2;


-- DML
INSERT INTO VALUTA (valuta_id, codice, descrizione, simbolo) VALUES
(1, 'EUR', 'Euro', '€'),
(2, 'USD', 'US Dollar', '$'),
(3, 'GBP', 'British Pound', '£'),
(4, 'CNY', 'Chinese Yuan', '¥'),
(5, 'JPY', 'Japanese Yen', '¥');

INSERT INTO CAMBIO_BUDGET (valuta_id, valore_cambio_eur) VALUES
(1.0, 1.0),
(2.0, 0.92),
(3.0, 1.17),
(4.0, 0.13),
(5.0, 0.006);

INSERT INTO SOCIETA (societa_id, nome, codice_fiscale, nazione, partita_iva) VALUES
(1, 'Altamira IT Co.', 'ALT-IT-001', 'IT', 'IT123456001'),
(2, 'Altamira FR Co.', 'ALT-FR-002', 'FR', 'FR123456002'),
(3, 'Altamira ES Co.', 'ALT-ES-003', 'ES', 'ES123456003'),
(4, 'Altamira DE Co.', 'ALT-DE-004', 'DE', 'DE123456004'),
(5, 'Altamira UK Co.', 'ALT-UK-005', 'UK', 'UK123456005'),
(6, 'Altamira US Co.', 'ALT-US-006', 'US', 'US123456006'),
(7, 'Altamira CN Co.', 'ALT-CN-007', 'CN', 'CN123456007'),
(8, 'Altamira JP Co.', 'ALT-JP-008', 'JP', 'JP123456008');

INSERT INTO CATEGORIA (categoria_id, nome) VALUES
(10, 'Bags'),
(20, 'Shoes'),
(30, 'RTW'),
(40, 'Small Leather Goods'),
(50, 'Accessories');

INSERT INTO MARCHIO (marchio_id, nome) VALUES
(100, 'Altamira'),
(200, 'Côte'),
(300, 'Linea Uno');

INSERT INTO STAGIONE (stagione_id, nome, data_inizio, data_fine) VALUES
(2401, 'SS-24', '2024-02-01', '2024-07-31'),
(2402, 'AW-24', '2024-08-01', '2025-01-31'),
(2501, 'SS-25', '2025-02-01', '2025-07-31'),
(2502, 'AW-25', '2025-08-01', '2026-01-31');

USE CATALOG fashion_catalog;
USE SCHEMA fashion_synthetic_2;


INSERT INTO PUNTO_VENDITA (punto_vendita_id, codice, nome, citta, paese, formato, societa_id, valuta_id) VALUES
(1, 'PV0001', 'IT Boutique Torino', 'Torino', 'IT', 'Boutique', 1, 1),
(2, 'PV0002', 'IT Flagship Milano', 'Milano', 'IT', 'Flagship', 1, 1),
(3, 'PV0003', 'IT Boutique Roma', 'Roma', 'IT', 'Boutique', 1, 1),
(4, 'PV0004', 'FR Flagship Marseille', 'Marseille', 'FR', 'Flagship', 2, 1),
(5, 'PV0005', 'FR Boutique Lyon', 'Lyon', 'FR', 'Boutique', 2, 1),
(6, 'PV0006', 'FR Boutique Lyon', 'Lyon', 'FR', 'Boutique', 2, 1),
(7, 'PV0007', 'ES Boutique Barcelona', 'Barcelona', 'ES', 'Boutique', 3, 1),
(8, 'PV0008', 'ES Flagship Madrid', 'Madrid', 'ES', 'Flagship', 3, 1),
(9, 'PV0009', 'ES Flagship Valencia', 'Valencia', 'ES', 'Flagship', 3, 1),
(10, 'PV0010', 'DE Flagship Hamburg', 'Hamburg', 'DE', 'Flagship', 4, 1),
(11, 'PV0011', 'DE Flagship Hamburg', 'Hamburg', 'DE', 'Flagship', 4, 1),
(12, 'PV0012', 'DE Boutique Berlin', 'Berlin', 'DE', 'Boutique', 4, 1),
(13, 'PV0013', 'UK Boutique Birmingham', 'Birmingham', 'UK', 'Boutique', 5, 3),
(14, 'PV0014', 'UK Boutique London', 'London', 'UK', 'Boutique', 5, 3),
(15, 'PV0015', 'UK Flagship London', 'London', 'UK', 'Flagship', 5, 3),
(16, 'PV0016', 'US Boutique Chicago', 'Chicago', 'US', 'Boutique', 6, 2),
(17, 'PV0017', 'US Outlet San Francisco', 'San Francisco', 'US', 'Outlet', 6, 2),
(18, 'PV0018', 'US Boutique New York', 'New York', 'US', 'Boutique', 6, 2),
(19, 'PV0019', 'CN Flagship Shanghai', 'Shanghai', 'CN', 'Flagship', 7, 4),
(20, 'PV0020', 'CN Flagship Shenzhen', 'Shenzhen', 'CN', 'Flagship', 7, 4),
(21, 'PV0021', 'CN Boutique Shenzhen', 'Shenzhen', 'CN', 'Boutique', 7, 4),
(22, 'PV0022', 'JP Boutique Osaka', 'Osaka', 'JP', 'Boutique', 8, 5),
(23, 'PV0023', 'JP Outlet Osaka', 'Osaka', 'JP', 'Outlet', 8, 5),
(24, 'PV0024', 'JP Flagship Tokyo', 'Tokyo', 'JP', 'Flagship', 8, 5),
(25, 'PV0025', 'FR Flagship Lyon', 'Lyon', 'FR', 'Flagship', 2, 1),
(26, 'PV0026', 'JP Flagship Yokohama', 'Yokohama', 'JP', 'Flagship', 8, 5),
(27, 'PV0027', 'ES Flagship Madrid', 'Madrid', 'ES', 'Flagship', 3, 1),
(28, 'PV0028', 'UK Outlet Birmingham', 'Birmingham', 'UK', 'Outlet', 5, 3),
(29, 'PV0029', 'CN Flagship Beijing', 'Beijing', 'CN', 'Flagship', 7, 4),
(30, 'PV0030', 'IT Boutique Milano', 'Milano', 'IT', 'Boutique', 1, 1);

INSERT INTO CLIENTE (cliente_id, nome, genere, nazione) VALUES
(1, 'Marta Marin', 'F', 'DE'),
(2, 'Yuki Zhang', 'M', 'DE'),
(3, 'Anna Marin', 'F', 'JP'),
(4, 'David Zhang', 'F', 'UK'),
(5, 'Nina Verdi', 'M', 'CN'),
(6, 'Oliver Rossi', 'F', 'ES'),
(7, 'Nina Anderson', 'M', 'ES'),
(8, 'David Müller', 'F', 'UK'),
(9, 'Yuki Sato', 'F', 'JP'),
(10, 'Sofia Müller', 'F', 'ES'),
(11, 'Sara Garcia', 'F', 'IT'),
(12, 'David Bianchi', 'M', 'FR'),
(13, 'Sara Bianchi', 'F', 'CN'),
(14, 'Luca Johnson', 'M', 'JP'),
(15, 'John Bianchi', 'M', 'CN'),
(16, 'Anna Anderson', 'F', 'UK'),
(17, 'Sofia Kim', 'F', 'CN'),
(18, 'Pierre Rossi', 'M', 'FR'),
(19, 'Nina Müller', 'F', 'ES'),
(20, 'James Hernandez', 'M', 'IT'),
(21, 'Ming Dubois', 'M', 'UK'),
(22, 'Emma Li', 'F', 'US'),
(23, 'Emma Garcia', 'F', 'US'),
(24, 'Ming Kobayashi', 'F', 'CN'),
(25, 'Oliver Dubois', 'M', 'ES'),
(26, 'Pierre Kobayashi', 'M', 'DE'),
(27, 'Alex Garcia', 'F', 'CN'),
(28, 'Nina Zhang', 'F', 'US'),
(29, 'Emma Martin', 'F', 'IT'),
(30, 'John Kobayashi', 'M', 'IT'),
(31, 'Oliver Smith', 'F', 'ES'),
(32, 'Wei Li', 'F', 'IT'),
(33, 'Giulia Conti', 'M', 'UK'),
(34, 'Giulia Rossi', 'F', 'US'),
(35, 'Sofia Garcia', 'M', 'UK'),
(36, 'Sara Hernandez', 'F', 'CN'),
(37, 'Anna Brown', 'M', 'US'),
(38, 'David Kobayashi', 'F', 'CN'),
(39, 'Sofia Conti', 'M', 'JP'),
(40, 'Alex Hernandez', 'M', 'US'),
(41, 'John Zhang', 'M', 'CN'),
(42, 'Elena Müller', 'F', 'FR'),
(43, 'Luca Marin', 'M', 'JP'),
(44, 'Hiro Kim', 'F', 'CN'),
(45, 'Ming Bianchi', 'M', 'JP'),
(46, 'Nina Sato', 'F', 'FR'),
(47, 'James Brown', 'M', 'FR'),
(48, 'Giulia Hernandez', 'F', 'FR'),
(49, 'Alex Müller', 'M', 'UK'),
(50, 'John Bianchi', 'M', 'FR'),
(51, 'John Müller', 'F', 'FR'),
(52, 'Oliver Anderson', 'M', 'ES'),
(53, 'Wei Bianchi', 'M', 'FR'),
(54, 'Oliver Anderson', 'M', 'FR'),
(55, 'David Kim', 'M', 'IT'),
(56, 'Anna Marin', 'F', 'IT'),
(57, 'Nina Marin', 'M', 'US'),
(58, 'Marta Müller', 'M', 'CN'),
(59, 'James Garcia', 'M', 'US'),
(60, 'Anna Brown', 'F', 'US'),
(61, 'James Verdi', 'F', 'IT'),
(62, 'Elena Dubois', 'M', 'FR'),
(63, 'Ming Kim', 'F', 'UK'),
(64, 'James Rossi', 'M', 'US'),
(65, 'Giulia Hernandez', 'F', 'US'),
(66, 'Hiro Müller', 'F', 'FR'),
(67, 'Luca Bianchi', 'M', 'CN'),
(68, 'Marco Smith', 'F', 'JP'),
(69, 'Giulia Verdi', 'M', 'FR'),
(70, 'Sara Li', 'M', 'US'),
(71, 'Elena Zhang', 'M', 'UK'),
(72, 'Alex Bianchi', 'M', 'CN'),
(73, 'Emma Kim', 'F', 'US'),
(74, 'Marta Anderson', 'M', 'JP'),
(75, 'Giulia Rossi', 'F', 'JP'),
(76, 'David Zhang', 'M', 'DE'),
(77, 'Pierre Dubois', 'M', 'US'),
(78, 'John Conti', 'F', 'ES'),
(79, 'Oliver Dubois', 'M', 'UK'),
(80, 'David Zhang', 'M', 'FR'),
(81, 'Elena Hernandez', 'M', 'US'),
(82, 'Hiro Verdi', 'M', 'CN'),
(83, 'Marco Lopez', 'M', 'IT'),
(84, 'David Hernandez', 'M', 'CN'),
(85, 'Hiro Conti', 'F', 'JP'),
(86, 'John Sato', 'M', 'US'),
(87, 'Pierre Dubois', 'M', 'IT'),
(88, 'Emma Rossi', 'F', 'CN'),
(89, 'Anna Bianchi', 'F', 'ES'),
(90, 'Giulia Bianchi', 'M', 'DE'),
(91, 'Giulia Hernandez', 'F', 'IT'),
(92, 'Marco Garcia', 'M', 'IT'),
(93, 'Hiro Li', 'F', 'CN'),
(94, 'Emma Brown', 'M', 'JP'),
(95, 'Pierre Garcia', 'F', 'ES'),
(96, 'Elena Anderson', 'F', 'JP'),
(97, 'John Johnson', 'M', 'CN'),
(98, 'Elena Sato', 'M', 'IT'),
(99, 'Hiro Marin', 'F', 'IT'),
(100, 'Yuki Lopez', 'F', 'CN'),
(101, 'Hiro Smith', 'F', 'IT'),
(102, 'Elena Sato', 'M', 'ES'),
(103, 'Giulia Martin', 'F', 'JP'),
(104, 'Oliver Martin', 'F', 'IT'),
(105, 'Yuki Zhang', 'F', 'US'),
(106, 'Hiro Lopez', 'F', 'CN'),
(107, 'Marco Kobayashi', 'F', 'JP'),
(108, 'Oliver Smith', 'M', 'UK'),
(109, 'Oliver Kobayashi', 'F', 'ES'),
(110, 'Marco Anderson', 'F', 'DE'),
(111, 'Oliver Marin', 'M', 'US'),
(112, 'Alex Kim', 'F', 'DE'),
(113, 'Sofia Kim', 'F', 'CN'),
(114, 'John Johnson', 'F', 'UK'),
(115, 'Nina Johnson', 'M', 'JP'),
(116, 'Oliver Verdi', 'M', 'FR'),
(117, 'Pierre Conti', 'F', 'DE'),
(118, 'Marta Verdi', 'F', 'CN'),
(119, 'Anna Johnson', 'F', 'US'),
(120, 'Marta Garcia', 'M', 'IT'),
(121, 'Elena Kobayashi', 'M', 'US'),
(122, 'Elena Martin', 'F', 'DE'),
(123, 'Hiro Brown', 'F', 'JP'),
(124, 'Ming Smith', 'M', 'US'),
(125, 'Sofia Dubois', 'M', 'CN'),
(126, 'Marta Bianchi', 'F', 'CN'),
(127, 'Pierre Lopez', 'F', 'JP'),
(128, 'Marta Johnson', 'M', 'FR'),
(129, 'Sofia Marin', 'F', 'JP'),
(130, 'Luca Sato', 'M', 'US'),
(131, 'James Zhang', 'F', 'CN'),
(132, 'Wei Bianchi', 'M', 'JP'),
(133, 'Elena Verdi', 'F', 'JP'),
(134, 'Luca Kim', 'F', 'US'),
(135, 'Sofia Rossi', 'M', 'UK'),
(136, 'Yuki Hernandez', 'F', 'JP'),
(137, 'Hiro Smith', 'M', 'US'),
(138, 'Sofia Kim', 'F', 'DE'),
(139, 'Ming Martin', 'M', 'IT'),
(140, 'Giulia Brown', 'F', 'CN'),
(141, 'David Marin', 'M', 'IT'),
(142, 'James Garcia', 'F', 'US'),
(143, 'Giulia Smith', 'F', 'CN'),
(144, 'James Dubois', 'F', 'US'),
(145, 'Alex Kobayashi', 'F', 'ES'),
(146, 'Sara Dubois', 'M', 'DE'),
(147, 'Giulia Johnson', 'F', 'US'),
(148, 'Oliver Zhang', 'M', 'JP'),
(149, 'Yuki Sato', 'M', 'FR'),
(150, 'John Verdi', 'M', 'DE'),
(151, 'Marta Conti', 'F', 'US'),
(152, 'Anna Zhang', 'F', 'IT'),
(153, 'Luca Conti', 'F', 'CN'),
(154, 'Emma Verdi', 'F', 'US'),
(155, 'Anna Martin', 'M', 'CN'),
(156, 'Oliver Conti', 'F', 'IT'),
(157, 'Luca Rossi', 'F', 'ES'),
(158, 'Luca Zhang', 'F', 'UK'),
(159, 'Emma Kobayashi', 'M', 'ES'),
(160, 'Elena Rossi', 'M', 'IT'),
(161, 'Wei Müller', 'M', 'FR'),
(162, 'Marta Rossi', 'M', 'US'),
(163, 'Marta Johnson', 'F', 'CN'),
(164, 'Wei Martin', 'M', 'ES'),
(165, 'Yuki Marin', 'F', 'US'),
(166, 'David Bianchi', 'F', 'US'),
(167, 'Wei Kim', 'M', 'FR'),
(168, 'Sofia Kobayashi', 'M', 'DE'),
(169, 'Emma Kobayashi', 'F', 'CN'),
(170, 'Sofia Brown', 'F', 'US'),
(171, 'Elena Conti', 'M', 'US'),
(172, 'Wei Conti', 'F', 'US'),
(173, 'Marta Marin', 'F', 'FR'),
(174, 'Ming Rossi', 'F', 'US'),
(175, 'Sofia Kobayashi', 'M', 'UK'),
(176, 'Marco Martin', 'M', 'IT'),
(177, 'Pierre Marin', 'M', 'UK'),
(178, 'Elena Li', 'F', 'US'),
(179, 'David Zhang', 'F', 'DE'),
(180, 'Ming Conti', 'M', 'CN'),
(181, 'Alex Garcia', 'F', 'JP'),
(182, 'James Dubois', 'F', 'IT'),
(183, 'Wei Sato', 'F', 'JP'),
(184, 'Ming Smith', 'F', 'JP'),
(185, 'Anna Smith', 'F', 'UK'),
(186, 'Emma Kim', 'M', 'UK'),
(187, 'Wei Anderson', 'F', 'US'),
(188, 'Sara Hernandez', 'F', 'US'),
(189, 'Alex Sato', 'F', 'CN'),
(190, 'Yuki Rossi', 'F', 'US'),
(191, 'John Marin', 'M', 'FR'),
(192, 'Oliver Kim', 'F', 'JP'),
(193, 'Yuki Bianchi', 'F', 'US'),
(194, 'Ming Kobayashi', 'M', 'UK'),
(195, 'Elena Martin', 'F', 'IT'),
(196, 'Emma Marin', 'F', 'US'),
(197, 'Luca Verdi', 'M', 'FR'),
(198, 'Emma Bianchi', 'F', 'ES'),
(199, 'James Anderson', 'F', 'ES'),
(200, 'Luca Sato', 'M', 'UK'),
(201, 'Alex Li', 'F', 'UK'),
(202, 'Emma Brown', 'M', 'IT'),
(203, 'Alex Sato', 'F', 'IT'),
(204, 'Oliver Verdi', 'M', 'ES'),
(205, 'Pierre Sato', 'M', 'CN'),
(206, 'John Hernandez', 'F', 'IT'),
(207, 'Marta Zhang', 'M', 'CN'),
(208, 'David Li', 'M', 'IT'),
(209, 'Marta Li', 'M', 'JP'),
(210, 'Marco Johnson', 'F', 'FR'),
(211, 'Pierre Verdi', 'M', 'CN'),
(212, 'Alex Zhang', 'M', 'CN'),
(213, 'Anna Garcia', 'F', 'CN'),
(214, 'Elena Sato', 'F', 'UK'),
(215, 'Alex Bianchi', 'M', 'UK'),
(216, 'Oliver Sato', 'M', 'US'),
(217, 'Ming Smith', 'M', 'US'),
(218, 'Emma Lopez', 'M', 'US'),
(219, 'David Lopez', 'F', 'JP'),
(220, 'Oliver Li', 'F', 'UK'),
(221, 'Giulia Conti', 'M', 'CN'),
(222, 'Marco Conti', 'F', 'US'),
(223, 'David Kim', 'F', 'FR'),
(224, 'Marta Brown', 'F', 'JP'),
(225, 'John Johnson', 'F', 'IT'),
(226, 'John Li', 'F', 'CN'),
(227, 'Wei Kobayashi', 'F', 'CN'),
(228, 'Marta Li', 'M', 'DE'),
(229, 'Nina Brown', 'F', 'JP'),
(230, 'Alex Verdi', 'F', 'FR'),
(231, 'Marco Sato', 'F', 'FR'),
(232, 'Wei Hernandez', 'F', 'CN'),
(233, 'Yuki Rossi', 'F', 'CN'),
(234, 'Elena Johnson', 'M', 'JP'),
(235, 'Ming Smith', 'F', 'IT'),
(236, 'Marta Brown', 'M', 'IT'),
(237, 'Ming Sato', 'F', 'JP'),
(238, 'Sofia Smith', 'M', 'CN'),
(239, 'Ming Dubois', 'F', 'IT'),
(240, 'James Hernandez', 'M', 'JP'),
(241, 'Oliver Sato', 'M', 'ES'),
(242, 'Pierre Hernandez', 'M', 'ES'),
(243, 'Marco Kobayashi', 'F', 'IT'),
(244, 'Anna Conti', 'M', 'US'),
(245, 'Emma Kim', 'F', 'CN'),
(246, 'Elena Kim', 'F', 'US'),
(247, 'Nina Brown', 'F', 'IT'),
(248, 'Sara Rossi', 'M', 'FR'),
(249, 'Luca Marin', 'M', 'UK'),
(250, 'Pierre Verdi', 'M', 'FR'),
(251, 'Sofia Smith', 'F', 'FR'),
(252, 'Alex Zhang', 'M', 'DE'),
(253, 'Pierre Smith', 'F', 'US'),
(254, 'James Li', 'M', 'UK'),
(255, 'Sofia Li', 'M', 'CN'),
(256, 'Giulia Brown', 'M', 'FR'),
(257, 'Sofia Verdi', 'M', 'UK'),
(258, 'Pierre Smith', 'M', 'JP'),
(259, 'Marco Zhang', 'M', 'US'),
(260, 'Nina Sato', 'F', 'JP'),
(261, 'John Garcia', 'F', 'JP'),
(262, 'Marco Conti', 'M', 'FR'),
(263, 'Emma Verdi', 'F', 'US'),
(264, 'Sara Anderson', 'M', 'US'),
(265, 'Alex Bianchi', 'F', 'IT'),
(266, 'Alex Brown', 'F', 'FR'),
(267, 'Sara Kim', 'M', 'CN'),
(268, 'Sara Bianchi', 'F', 'CN'),
(269, 'Wei Conti', 'F', 'CN'),
(270, 'Sofia Hernandez', 'F', 'UK'),
(271, 'Oliver Sato', 'M', 'DE'),
(272, 'Ming Garcia', 'M', 'IT'),
(273, 'David Lopez', 'M', 'ES'),
(274, 'Marco Müller', 'F', 'US'),
(275, 'Anna Dubois', 'M', 'US'),
(276, 'David Marin', 'M', 'US'),
(277, 'Sofia Zhang', 'F', 'US'),
(278, 'Yuki Müller', 'M', 'US'),
(279, 'Pierre Kobayashi', 'M', 'JP'),
(280, 'John Sato', 'F', 'US'),
(281, 'Luca Martin', 'M', 'DE'),
(282, 'Luca Garcia', 'M', 'CN'),
(283, 'Wei Lopez', 'F', 'US'),
(284, 'Marco Verdi', 'F', 'IT'),
(285, 'Luca Kobayashi', 'M', 'DE'),
(286, 'Sara Conti', 'M', 'CN'),
(287, 'Sara Marin', 'F', 'IT'),
(288, 'Hiro Bianchi', 'M', 'ES'),
(289, 'Marco Rossi', 'M', 'US'),
(290, 'Anna Johnson', 'F', 'JP'),
(291, 'Wei Hernandez', 'F', 'US'),
(292, 'Alex Bianchi', 'M', 'US'),
(293, 'Luca Kim', 'M', 'CN'),
(294, 'Sara Garcia', 'F', 'US'),
(295, 'Giulia Rossi', 'F', 'US'),
(296, 'James Dubois', 'F', 'UK'),
(297, 'David Zhang', 'F', 'CN'),
(298, 'John Lopez', 'M', 'US'),
(299, 'Oliver Marin', 'F', 'CN'),
(300, 'Yuki Lopez', 'M', 'CN'),
(301, 'Ming Li', 'M', 'CN'),
(302, 'Pierre Sato', 'F', 'US'),
(303, 'Yuki Garcia', 'M', 'CN'),
(304, 'David Smith', 'M', 'FR'),
(305, 'Marta Rossi', 'M', 'JP'),
(306, 'Emma Verdi', 'F', 'DE'),
(307, 'Nina Sato', 'M', 'UK'),
(308, 'Alex Sato', 'F', 'JP'),
(309, 'John Dubois', 'F', 'CN'),
(310, 'Nina Marin', 'M', 'JP'),
(311, 'Alex Smith', 'M', 'US'),
(312, 'Sara Marin', 'M', 'UK'),
(313, 'Anna Marin', 'M', 'UK'),
(314, 'Nina Marin', 'M', 'US'),
(315, 'Nina Verdi', 'M', 'IT'),
(316, 'Hiro Brown', 'F', 'US'),
(317, 'Nina Müller', 'M', 'US'),
(318, 'Emma Sato', 'M', 'CN'),
(319, 'John Johnson', 'F', 'IT'),
(320, 'Luca Li', 'F', 'FR'),
(321, 'Emma Johnson', 'M', 'JP'),
(322, 'Luca Smith', 'F', 'CN'),
(323, 'Anna Li', 'F', 'UK'),
(324, 'Pierre Kobayashi', 'F', 'DE'),
(325, 'James Martin', 'M', 'IT'),
(326, 'Emma Lopez', 'F', 'UK'),
(327, 'Oliver Rossi', 'F', 'FR'),
(328, 'Sofia Smith', 'M', 'JP'),
(329, 'Luca Lopez', 'M', 'IT'),
(330, 'James Garcia', 'F', 'CN'),
(331, 'David Verdi', 'F', 'JP'),
(332, 'Sofia Kim', 'F', 'US'),
(333, 'Yuki Hernandez', 'F', 'DE'),
(334, 'Sofia Dubois', 'M', 'DE'),
(335, 'Marco Martin', 'F', 'JP'),
(336, 'Yuki Kobayashi', 'M', 'UK'),
(337, 'James Lopez', 'M', 'IT'),
(338, 'Nina Conti', 'F', 'IT'),
(339, 'Anna Kim', 'M', 'ES'),
(340, 'David Verdi', 'M', 'US'),
(341, 'Elena Garcia', 'M', 'JP'),
(342, 'Hiro Bianchi', 'F', 'DE'),
(343, 'Giulia Kim', 'M', 'US'),
(344, 'James Johnson', 'M', 'CN'),
(345, 'Emma Bianchi', 'M', 'UK'),
(346, 'Nina Lopez', 'M', 'JP'),
(347, 'Alex Marin', 'M', 'UK'),
(348, 'Anna Anderson', 'F', 'IT'),
(349, 'Nina Brown', 'M', 'CN'),
(350, 'Elena Sato', 'M', 'US'),
(351, 'David Kobayashi', 'F', 'DE'),
(352, 'Giulia Müller', 'M', 'ES'),
(353, 'Marta Kobayashi', 'M', 'ES'),
(354, 'Alex Dubois', 'F', 'CN'),
(355, 'Pierre Rossi', 'M', 'ES'),
(356, 'Nina Lopez', 'M', 'CN'),
(357, 'Oliver Martin', 'F', 'FR'),
(358, 'James Lopez', 'M', 'JP'),
(359, 'Pierre Hernandez', 'M', 'UK'),
(360, 'Yuki Kim', 'F', 'US'),
(361, 'John Martin', 'F', 'US'),
(362, 'Marco Bianchi', 'F', 'CN'),
(363, 'Marta Zhang', 'F', 'ES'),
(364, 'Sofia Conti', 'M', 'FR'),
(365, 'David Johnson', 'F', 'UK'),
(366, 'James Dubois', 'F', 'FR'),
(367, 'James Kim', 'M', 'JP'),
(368, 'Anna Garcia', 'M', 'US'),
(369, 'Elena Garcia', 'M', 'IT'),
(370, 'Yuki Verdi', 'F', 'FR'),
(371, 'Elena Müller', 'M', 'DE'),
(372, 'Emma Rossi', 'M', 'IT'),
(373, 'Hiro Garcia', 'F', 'DE'),
(374, 'Elena Li', 'M', 'FR'),
(375, 'Sofia Brown', 'F', 'US'),
(376, 'Sofia Johnson', 'M', 'CN'),
(377, 'Oliver Johnson', 'M', 'US'),
(378, 'Yuki Rossi', 'M', 'CN'),
(379, 'James Brown', 'F', 'CN'),
(380, 'John Li', 'F', 'US'),
(381, 'James Anderson', 'M', 'US'),
(382, 'Alex Dubois', 'M', 'JP'),
(383, 'Emma Garcia', 'F', 'UK'),
(384, 'Marta Kobayashi', 'M', 'FR'),
(385, 'Alex Bianchi', 'M', 'JP'),
(386, 'Ming Verdi', 'F', 'JP'),
(387, 'David Marin', 'M', 'CN'),
(388, 'Luca Kim', 'F', 'JP'),
(389, 'Ming Müller', 'M', 'IT'),
(390, 'Nina Müller', 'F', 'ES'),
(391, 'John Garcia', 'F', 'DE'),
(392, 'Pierre Li', 'M', 'FR'),
(393, 'Nina Lopez', 'F', 'US'),
(394, 'Yuki Dubois', 'M', 'JP'),
(395, 'Pierre Conti', 'F', 'US'),
(396, 'Alex Brown', 'M', 'FR'),
(397, 'Luca Conti', 'F', 'JP'),
(398, 'Marco Anderson', 'M', 'JP'),
(399, 'Alex Martin', 'F', 'JP'),
(400, 'Sofia Brown', 'M', 'JP'),
(401, 'Nina Brown', 'M', 'FR'),
(402, 'Pierre Conti', 'M', 'IT'),
(403, 'Giulia Johnson', 'M', 'US'),
(404, 'Sofia Anderson', 'F', 'US'),
(405, 'Oliver Johnson', 'F', 'ES'),
(406, 'John Hernandez', 'F', 'JP'),
(407, 'Sofia Martin', 'F', 'DE'),
(408, 'James Kim', 'F', 'UK'),
(409, 'Wei Smith', 'M', 'FR'),
(410, 'Nina Sato', 'F', 'UK'),
(411, 'Marta Rossi', 'M', 'CN'),
(412, 'Emma Garcia', 'M', 'ES'),
(413, 'Wei Zhang', 'M', 'JP'),
(414, 'Ming Martin', 'M', 'US'),
(415, 'Anna Kim', 'F', 'JP'),
(416, 'Hiro Martin', 'M', 'FR'),
(417, 'Marta Rossi', 'M', 'FR'),
(418, 'Pierre Verdi', 'M', 'DE'),
(419, 'Hiro Marin', 'M', 'FR'),
(420, 'Alex Anderson', 'M', 'ES'),
(421, 'Giulia Zhang', 'F', 'JP'),
(422, 'Anna Martin', 'M', 'FR'),
(423, 'Alex Garcia', 'F', 'CN'),
(424, 'David Li', 'M', 'IT'),
(425, 'John Dubois', 'M', 'FR'),
(426, 'Sara Johnson', 'M', 'FR'),
(427, 'Alex Marin', 'F', 'JP'),
(428, 'David Hernandez', 'F', 'DE'),
(429, 'Ming Conti', 'M', 'CN'),
(430, 'John Sato', 'F', 'UK'),
(431, 'Luca Marin', 'M', 'US'),
(432, 'Marta Smith', 'F', 'ES'),
(433, 'Hiro Kobayashi', 'F', 'IT'),
(434, 'Nina Dubois', 'M', 'IT'),
(435, 'Pierre Johnson', 'M', 'IT'),
(436, 'Alex Rossi', 'M', 'UK'),
(437, 'Elena Kobayashi', 'F', 'DE'),
(438, 'Nina Kim', 'M', 'UK'),
(439, 'Marco Zhang', 'M', 'US'),
(440, 'Yuki Hernandez', 'M', 'ES'),
(441, 'Oliver Li', 'M', 'US'),
(442, 'Pierre Dubois', 'F', 'CN'),
(443, 'Anna Sato', 'M', 'FR'),
(444, 'Oliver Kim', 'F', 'CN'),
(445, 'John Verdi', 'M', 'IT'),
(446, 'Alex Johnson', 'M', 'IT'),
(447, 'Sofia Dubois', 'F', 'CN'),
(448, 'Giulia Rossi', 'M', 'US'),
(449, 'Alex Smith', 'M', 'US'),
(450, 'Hiro Kobayashi', 'M', 'CN'),
(451, 'Anna Rossi', 'F', 'JP'),
(452, 'John Marin', 'M', 'JP'),
(453, 'Luca Anderson', 'M', 'US'),
(454, 'Yuki Müller', 'F', 'ES'),
(455, 'Sara Garcia', 'M', 'JP'),
(456, 'Hiro Martin', 'M', 'JP'),
(457, 'Luca Anderson', 'M', 'IT'),
(458, 'Luca Kim', 'F', 'FR'),
(459, 'David Lopez', 'F', 'CN'),
(460, 'Wei Lopez', 'F', 'JP'),
(461, 'Elena Verdi', 'M', 'US'),
(462, 'David Anderson', 'M', 'US'),
(463, 'Giulia Johnson', 'M', 'JP'),
(464, 'John Zhang', 'M', 'US'),
(465, 'Luca Li', 'F', 'CN'),
(466, 'John Zhang', 'F', 'UK'),
(467, 'Sofia Conti', 'F', 'JP'),
(468, 'Marco Dubois', 'F', 'JP'),
(469, 'Yuki Conti', 'M', 'CN'),
(470, 'Anna Garcia', 'M', 'US'),
(471, 'Sofia Kobayashi', 'M', 'CN'),
(472, 'Giulia Müller', 'M', 'JP'),
(473, 'Luca Zhang', 'M', 'US'),
(474, 'John Anderson', 'F', 'US'),
(475, 'Marta Rossi', 'M', 'US'),
(476, 'Sofia Martin', 'M', 'DE'),
(477, 'Anna Lopez', 'F', 'FR'),
(478, 'Sofia Lopez', 'M', 'US'),
(479, 'Sara Marin', 'M', 'FR'),
(480, 'David Kim', 'M', 'CN'),
(481, 'Ming Kim', 'F', 'JP'),
(482, 'Pierre Lopez', 'M', 'FR'),
(483, 'Luca Bianchi', 'F', 'US'),
(484, 'Oliver Brown', 'M', 'IT'),
(485, 'Luca Marin', 'F', 'US'),
(486, 'Giulia Bianchi', 'F', 'UK'),
(487, 'Ming Brown', 'M', 'US'),
(488, 'David Li', 'M', 'US'),
(489, 'Sara Kim', 'M', 'JP'),
(490, 'Marco Müller', 'F', 'CN'),
(491, 'James Marin', 'M', 'UK'),
(492, 'Pierre Lopez', 'F', 'FR'),
(493, 'Wei Conti', 'F', 'JP'),
(494, 'Ming Johnson', 'M', 'DE'),
(495, 'Emma Lopez', 'F', 'JP'),
(496, 'Marta Johnson', 'M', 'JP'),
(497, 'Pierre Li', 'F', 'JP'),
(498, 'Ming Sato', 'F', 'DE'),
(499, 'Marco Sato', 'F', 'FR'),
(500, 'John Martin', 'F', 'US'),
(501, 'Marta Rossi', 'M', 'DE'),
(502, 'Anna Kobayashi', 'F', 'CN'),
(503, 'Marco Lopez', 'F', 'US'),
(504, 'Marco Garcia', 'M', 'UK'),
(505, 'James Johnson', 'M', 'IT'),
(506, 'Marta Müller', 'M', 'ES'),
(507, 'Marta Li', 'M', 'CN'),
(508, 'Alex Smith', 'M', 'US'),
(509, 'Yuki Martin', 'F', 'JP'),
(510, 'Alex Anderson', 'F', 'US'),
(511, 'Alex Lopez', 'M', 'CN'),
(512, 'Yuki Kobayashi', 'M', 'IT'),
(513, 'James Bianchi', 'F', 'JP'),
(514, 'Yuki Hernandez', 'F', 'UK'),
(515, 'Nina Bianchi', 'M', 'US'),
(516, 'Sara Li', 'M', 'DE'),
(517, 'Ming Dubois', 'F', 'JP'),
(518, 'Hiro Müller', 'M', 'US'),
(519, 'Ming Martin', 'M', 'CN'),
(520, 'Oliver Verdi', 'F', 'ES'),
(521, 'Oliver Lopez', 'M', 'US'),
(522, 'Sofia Li', 'F', 'ES'),
(523, 'Marta Rossi', 'F', 'UK'),
(524, 'Elena Johnson', 'F', 'JP'),
(525, 'Wei Kobayashi', 'F', 'JP'),
(526, 'Marco Li', 'F', 'IT'),
(527, 'Alex Conti', 'M', 'FR'),
(528, 'Alex Marin', 'M', 'IT'),
(529, 'Sofia Smith', 'F', 'CN'),
(530, 'Giulia Martin', 'M', 'IT'),
(531, 'Pierre Hernandez', 'F', 'CN'),
(532, 'Marta Smith', 'F', 'IT'),
(533, 'Emma Li', 'M', 'JP'),
(534, 'Oliver Johnson', 'F', 'US'),
(535, 'Marco Garcia', 'F', 'US'),
(536, 'Sara Müller', 'F', 'FR'),
(537, 'David Müller', 'M', 'CN'),
(538, 'Anna Marin', 'F', 'CN'),
(539, 'Sara Hernandez', 'F', 'CN'),
(540, 'Pierre Smith', 'M', 'IT'),
(541, 'John Sato', 'F', 'DE'),
(542, 'John Lopez', 'M', 'JP'),
(543, 'Alex Kobayashi', 'M', 'CN'),
(544, 'David Lopez', 'F', 'CN'),
(545, 'Emma Sato', 'F', 'ES'),
(546, 'David Müller', 'F', 'DE'),
(547, 'Marco Martin', 'M', 'CN'),
(548, 'David Marin', 'F', 'JP'),
(549, 'Wei Li', 'F', 'FR'),
(550, 'Anna Rossi', 'M', 'ES'),
(551, 'Marco Smith', 'M', 'FR'),
(552, 'David Smith', 'M', 'IT'),
(553, 'Sara Lopez', 'M', 'UK'),
(554, 'Alex Dubois', 'M', 'FR'),
(555, 'John Marin', 'M', 'IT'),
(556, 'Nina Martin', 'F', 'US'),
(557, 'David Kim', 'F', 'JP'),
(558, 'Elena Sato', 'F', 'FR'),
(559, 'Elena Kim', 'M', 'UK'),
(560, 'Sofia Martin', 'M', 'DE'),
(561, 'Hiro Marin', 'M', 'ES'),
(562, 'David Hernandez', 'F', 'CN'),
(563, 'Anna Martin', 'F', 'JP'),
(564, 'Giulia Conti', 'F', 'US'),
(565, 'Marco Bianchi', 'M', 'JP'),
(566, 'Wei Rossi', 'F', 'JP'),
(567, 'John Lopez', 'F', 'US'),
(568, 'James Smith', 'F', 'FR'),
(569, 'Marco Anderson', 'M', 'DE'),
(570, 'Wei Brown', 'M', 'US'),
(571, 'Ming Anderson', 'M', 'JP'),
(572, 'Ming Smith', 'M', 'FR'),
(573, 'Anna Hernandez', 'F', 'JP'),
(574, 'John Conti', 'F', 'US'),
(575, 'Wei Garcia', 'F', 'ES'),
(576, 'Yuki Li', 'F', 'CN'),
(577, 'David Kobayashi', 'M', 'US'),
(578, 'Yuki Müller', 'F', 'JP'),
(579, 'Luca Conti', 'M', 'CN'),
(580, 'Sara Sato', 'M', 'US'),
(581, 'Pierre Li', 'F', 'ES'),
(582, 'Yuki Anderson', 'M', 'IT'),
(583, 'Sara Zhang', 'M', 'US'),
(584, 'Nina Johnson', 'F', 'IT'),
(585, 'Luca Kim', 'M', 'DE'),
(586, 'Hiro Zhang', 'F', 'IT'),
(587, 'David Garcia', 'F', 'DE'),
(588, 'David Lopez', 'F', 'JP'),
(589, 'David Bianchi', 'M', 'ES'),
(590, 'James Müller', 'M', 'CN'),
(591, 'Pierre Dubois', 'M', 'JP'),
(592, 'John Conti', 'M', 'IT'),
(593, 'Marco Anderson', 'F', 'JP'),
(594, 'John Martin', 'M', 'DE'),
(595, 'Hiro Anderson', 'M', 'JP'),
(596, 'John Lopez', 'M', 'CN'),
(597, 'Wei Garcia', 'M', 'DE'),
(598, 'David Li', 'F', 'IT'),
(599, 'Hiro Rossi', 'F', 'IT'),
(600, 'Marta Rossi', 'F', 'US'),
(601, 'James Marin', 'M', 'IT'),
(602, 'Ming Dubois', 'F', 'IT'),
(603, 'Luca Brown', 'M', 'JP'),
(604, 'Marco Sato', 'F', 'JP'),
(605, 'John Sato', 'M', 'JP'),
(606, 'Emma Martin', 'F', 'IT'),
(607, 'Nina Dubois', 'F', 'IT'),
(608, 'Ming Smith', 'M', 'JP'),
(609, 'David Zhang', 'M', 'US'),
(610, 'Wei Li', 'M', 'JP'),
(611, 'James Garcia', 'M', 'CN'),
(612, 'Marco Smith', 'F', 'DE'),
(613, 'Anna Rossi', 'F', 'IT'),
(614, 'Hiro Rossi', 'M', 'UK'),
(615, 'Marco Brown', 'M', 'FR'),
(616, 'Yuki Hernandez', 'F', 'UK'),
(617, 'Elena Anderson', 'F', 'US'),
(618, 'Nina Johnson', 'F', 'US'),
(619, 'Elena Müller', 'M', 'FR'),
(620, 'Yuki Smith', 'M', 'US'),
(621, 'Wei Verdi', 'F', 'DE'),
(622, 'Wei Garcia', 'F', 'UK'),
(623, 'Hiro Garcia', 'F', 'JP'),
(624, 'David Dubois', 'F', 'JP'),
(625, 'Sara Brown', 'F', 'US'),
(626, 'Sara Lopez', 'M', 'DE'),
(627, 'Anna Kobayashi', 'F', 'IT'),
(628, 'Marco Sato', 'M', 'US'),
(629, 'Hiro Johnson', 'F', 'JP'),
(630, 'Hiro Garcia', 'F', 'CN'),
(631, 'Anna Kobayashi', 'F', 'FR'),
(632, 'Luca Zhang', 'F', 'JP'),
(633, 'Marta Kobayashi', 'M', 'FR'),
(634, 'Anna Garcia', 'M', 'DE'),
(635, 'Marco Verdi', 'M', 'DE'),
(636, 'Alex Hernandez', 'M', 'JP'),
(637, 'Nina Sato', 'F', 'CN'),
(638, 'Oliver Kobayashi', 'F', 'UK'),
(639, 'Pierre Martin', 'M', 'US'),
(640, 'Hiro Garcia', 'M', 'ES'),
(641, 'Giulia Müller', 'F', 'UK'),
(642, 'Wei Marin', 'F', 'UK'),
(643, 'Oliver Anderson', 'F', 'UK'),
(644, 'Pierre Anderson', 'F', 'US'),
(645, 'Luca Johnson', 'F', 'US'),
(646, 'David Li', 'F', 'US'),
(647, 'Elena Hernandez', 'F', 'FR'),
(648, 'Yuki Martin', 'M', 'JP'),
(649, 'Emma Li', 'M', 'JP'),
(650, 'Hiro Bianchi', 'F', 'ES'),
(651, 'Oliver Garcia', 'M', 'UK'),
(652, 'Alex Verdi', 'M', 'FR'),
(653, 'Elena Li', 'M', 'IT'),
(654, 'Elena Dubois', 'M', 'IT'),
(655, 'Sofia Martin', 'M', 'UK'),
(656, 'Sofia Verdi', 'F', 'IT'),
(657, 'Wei Garcia', 'M', 'CN'),
(658, 'John Bianchi', 'M', 'ES'),
(659, 'Wei Verdi', 'M', 'CN'),
(660, 'Wei Rossi', 'F', 'US'),
(661, 'Sofia Sato', 'F', 'IT'),
(662, 'John Brown', 'F', 'DE'),
(663, 'Elena Zhang', 'M', 'IT'),
(664, 'Sofia Müller', 'F', 'CN'),
(665, 'James Rossi', 'F', 'FR'),
(666, 'Luca Hernandez', 'F', 'US'),
(667, 'James Rossi', 'F', 'DE'),
(668, 'John Kobayashi', 'M', 'US'),
(669, 'Luca Lopez', 'F', 'CN'),
(670, 'Sara Verdi', 'F', 'FR'),
(671, 'Marco Johnson', 'M', 'US'),
(672, 'Sofia Conti', 'M', 'UK'),
(673, 'Marco Zhang', 'F', 'FR'),
(674, 'John Hernandez', 'F', 'US'),
(675, 'Emma Brown', 'F', 'IT'),
(676, 'Anna Smith', 'M', 'DE'),
(677, 'Oliver Sato', 'F', 'UK'),
(678, 'Marco Martin', 'M', 'UK'),
(679, 'Nina Lopez', 'M', 'US'),
(680, 'Nina Brown', 'M', 'JP'),
(681, 'Elena Müller', 'F', 'ES'),
(682, 'Yuki Verdi', 'F', 'IT'),
(683, 'Wei Johnson', 'M', 'JP'),
(684, 'Giulia Conti', 'M', 'CN'),
(685, 'David Verdi', 'F', 'CN'),
(686, 'Nina Bianchi', 'M', 'US'),
(687, 'Pierre Johnson', 'M', 'JP'),
(688, 'Elena Marin', 'M', 'US'),
(689, 'Nina Kobayashi', 'F', 'US'),
(690, 'Elena Johnson', 'M', 'US'),
(691, 'James Kobayashi', 'M', 'IT'),
(692, 'Wei Müller', 'M', 'IT'),
(693, 'Sara Müller', 'F', 'ES'),
(694, 'Nina Smith', 'M', 'US'),
(695, 'Yuki Lopez', 'F', 'JP'),
(696, 'Alex Sato', 'M', 'UK'),
(697, 'Yuki Smith', 'M', 'JP'),
(698, 'Oliver Li', 'F', 'FR'),
(699, 'Hiro Hernandez', 'M', 'FR'),
(700, 'James Li', 'F', 'JP'),
(701, 'Marta Kim', 'F', 'IT'),
(702, 'Alex Brown', 'M', 'FR'),
(703, 'Oliver Müller', 'M', 'FR'),
(704, 'Luca Anderson', 'F', 'IT'),
(705, 'Alex Rossi', 'M', 'UK'),
(706, 'John Smith', 'M', 'UK'),
(707, 'Giulia Kim', 'M', 'DE'),
(708, 'Sara Li', 'M', 'JP'),
(709, 'Alex Verdi', 'F', 'CN'),
(710, 'Ming Dubois', 'F', 'CN'),
(711, 'Ming Anderson', 'M', 'CN'),
(712, 'David Zhang', 'M', 'DE'),
(713, 'John Kim', 'M', 'US'),
(714, 'Oliver Rossi', 'M', 'CN'),
(715, 'Yuki Müller', 'F', 'IT'),
(716, 'Wei Verdi', 'M', 'CN'),
(717, 'Marta Anderson', 'F', 'ES'),
(718, 'Yuki Kobayashi', 'F', 'FR'),
(719, 'Marta Rossi', 'M', 'FR'),
(720, 'Elena Smith', 'M', 'JP'),
(721, 'Luca Müller', 'M', 'CN'),
(722, 'Elena Verdi', 'M', 'CN'),
(723, 'Alex Brown', 'M', 'DE'),
(724, 'Sara Lopez', 'M', 'JP'),
(725, 'Anna Conti', 'M', 'UK'),
(726, 'Hiro Verdi', 'M', 'CN'),
(727, 'Alex Conti', 'F', 'US'),
(728, 'Yuki Marin', 'M', 'JP'),
(729, 'Nina Bianchi', 'F', 'JP'),
(730, 'Anna Kobayashi', 'M', 'CN'),
(731, 'Ming Marin', 'M', 'FR'),
(732, 'Ming Lopez', 'M', 'IT'),
(733, 'Yuki Marin', 'M', 'JP'),
(734, 'Hiro Li', 'F', 'ES'),
(735, 'Luca Anderson', 'M', 'US'),
(736, 'David Verdi', 'F', 'IT'),
(737, 'Alex Bianchi', 'F', 'JP'),
(738, 'Emma Conti', 'M', 'FR'),
(739, 'James Müller', 'F', 'FR'),
(740, 'Sofia Hernandez', 'F', 'ES'),
(741, 'Nina Verdi', 'F', 'CN'),
(742, 'James Verdi', 'F', 'US'),
(743, 'Elena Dubois', 'F', 'US'),
(744, 'David Anderson', 'F', 'IT'),
(745, 'Marco Anderson', 'M', 'UK'),
(746, 'John Brown', 'F', 'IT'),
(747, 'Elena Lopez', 'M', 'ES'),
(748, 'Luca Smith', 'F', 'US'),
(749, 'Ming Verdi', 'M', 'FR'),
(750, 'Sofia Dubois', 'M', 'JP'),
(751, 'James Anderson', 'M', 'US'),
(752, 'Anna Martin', 'M', 'ES'),
(753, 'Luca Verdi', 'M', 'US'),
(754, 'Alex Dubois', 'M', 'US'),
(755, 'John Kim', 'M', 'FR'),
(756, 'John Li', 'F', 'CN'),
(757, 'Oliver Conti', 'M', 'US'),
(758, 'Luca Kobayashi', 'F', 'FR'),
(759, 'Oliver Kobayashi', 'M', 'IT'),
(760, 'Yuki Rossi', 'M', 'CN'),
(761, 'John Smith', 'M', 'US'),
(762, 'David Hernandez', 'M', 'CN'),
(763, 'Ming Brown', 'F', 'IT'),
(764, 'Elena Bianchi', 'F', 'FR'),
(765, 'Alex Johnson', 'F', 'CN'),
(766, 'John Kim', 'M', 'JP'),
(767, 'Pierre Sato', 'F', 'UK'),
(768, 'Elena Verdi', 'M', 'CN'),
(769, 'Nina Smith', 'M', 'JP'),
(770, 'Emma Brown', 'F', 'IT'),
(771, 'Sara Rossi', 'F', 'IT'),
(772, 'Sara Rossi', 'M', 'DE'),
(773, 'John Martin', 'F', 'JP'),
(774, 'Marco Marin', 'F', 'IT'),
(775, 'Wei Li', 'M', 'US'),
(776, 'David Bianchi', 'F', 'FR'),
(777, 'Anna Zhang', 'M', 'CN'),
(778, 'Oliver Conti', 'F', 'CN'),
(779, 'Giulia Kim', 'F', 'FR'),
(780, 'Marco Brown', 'M', 'US'),
(781, 'Nina Zhang', 'M', 'JP'),
(782, 'Marco Hernandez', 'M', 'US'),
(783, 'Emma Li', 'F', 'ES'),
(784, 'Marco Smith', 'F', 'UK'),
(785, 'Hiro Verdi', 'F', 'UK'),
(786, 'Pierre Kobayashi', 'M', 'CN'),
(787, 'Marta Müller', 'M', 'US'),
(788, 'James Anderson', 'F', 'ES'),
(789, 'Anna Conti', 'M', 'US'),
(790, 'Marta Rossi', 'F', 'ES'),
(791, 'Marta Garcia', 'M', 'ES'),
(792, 'Marta Brown', 'F', 'DE'),
(793, 'Emma Martin', 'M', 'IT'),
(794, 'Anna Lopez', 'F', 'US'),
(795, 'Giulia Johnson', 'F', 'FR'),
(796, 'Ming Dubois', 'F', 'JP'),
(797, 'Nina Bianchi', 'M', 'DE'),
(798, 'David Anderson', 'M', 'UK'),
(799, 'Giulia Anderson', 'F', 'US'),
(800, 'Marta Marin', 'F', 'DE'),
(801, 'John Sato', 'M', 'JP'),
(802, 'Luca Li', 'M', 'CN'),
(803, 'Ming Anderson', 'F', 'FR'),
(804, 'Nina Müller', 'M', 'ES'),
(805, 'Oliver Müller', 'F', 'IT'),
(806, 'Giulia Johnson', 'F', 'UK'),
(807, 'John Müller', 'M', 'CN'),
(808, 'Alex Marin', 'M', 'ES'),
(809, 'Ming Zhang', 'M', 'ES'),
(810, 'Giulia Zhang', 'F', 'CN'),
(811, 'Alex Hernandez', 'F', 'UK'),
(812, 'David Garcia', 'M', 'IT'),
(813, 'Luca Brown', 'M', 'IT'),
(814, 'Sara Brown', 'M', 'CN'),
(815, 'Anna Conti', 'M', 'IT'),
(816, 'David Anderson', 'F', 'ES'),
(817, 'Oliver Müller', 'M', 'US'),
(818, 'Sara Conti', 'M', 'ES'),
(819, 'Nina Kim', 'F', 'CN'),
(820, 'Sofia Conti', 'M', 'JP'),
(821, 'Nina Marin', 'F', 'US'),
(822, 'Marco Müller', 'F', 'US'),
(823, 'Anna Li', 'M', 'IT'),
(824, 'John Bianchi', 'F', 'US'),
(825, 'Luca Bianchi', 'M', 'IT'),
(826, 'Sofia Brown', 'F', 'CN'),
(827, 'Anna Hernandez', 'M', 'ES'),
(828, 'Emma Johnson', 'M', 'ES'),
(829, 'Elena Kim', 'F', 'JP'),
(830, 'John Hernandez', 'M', 'ES'),
(831, 'Pierre Kobayashi', 'F', 'ES'),
(832, 'Sofia Marin', 'M', 'FR'),
(833, 'Hiro Bianchi', 'F', 'FR'),
(834, 'Sara Bianchi', 'M', 'IT'),
(835, 'Wei Kobayashi', 'F', 'US'),
(836, 'Sara Bianchi', 'M', 'ES'),
(837, 'Wei Verdi', 'F', 'IT'),
(838, 'Luca Johnson', 'F', 'US'),
(839, 'Anna Smith', 'M', 'CN'),
(840, 'Sara Kim', 'M', 'JP'),
(841, 'David Rossi', 'F', 'IT'),
(842, 'Hiro Bianchi', 'F', 'IT'),
(843, 'Sara Müller', 'M', 'CN'),
(844, 'Nina Kim', 'F', 'CN'),
(845, 'Nina Brown', 'M', 'CN'),
(846, 'Alex Conti', 'M', 'CN'),
(847, 'Hiro Zhang', 'F', 'ES'),
(848, 'Oliver Zhang', 'M', 'CN'),
(849, 'Wei Li', 'F', 'US'),
(850, 'John Li', 'F', 'IT'),
(851, 'Luca Johnson', 'M', 'JP'),
(852, 'Sara Müller', 'F', 'US'),
(853, 'Hiro Marin', 'F', 'IT'),
(854, 'Luca Smith', 'M', 'FR'),
(855, 'Nina Sato', 'F', 'JP'),
(856, 'Giulia Sato', 'M', 'US'),
(857, 'Sara Smith', 'F', 'JP'),
(858, 'Ming Johnson', 'F', 'UK'),
(859, 'Hiro Hernandez', 'M', 'IT'),
(860, 'Marco Lopez', 'M', 'ES'),
(861, 'Wei Lopez', 'F', 'ES'),
(862, 'Oliver Johnson', 'M', 'ES'),
(863, 'Hiro Rossi', 'F', 'CN'),
(864, 'Yuki Johnson', 'M', 'CN'),
(865, 'Alex Lopez', 'M', 'IT'),
(866, 'John Sato', 'M', 'CN'),
(867, 'David Smith', 'F', 'ES'),
(868, 'John Conti', 'M', 'ES'),
(869, 'Anna Conti', 'M', 'IT'),
(870, 'Ming Marin', 'M', 'CN'),
(871, 'James Zhang', 'F', 'UK'),
(872, 'Nina Kim', 'F', 'CN'),
(873, 'David Sato', 'F', 'ES'),
(874, 'Marco Kobayashi', 'M', 'JP'),
(875, 'Marta Kobayashi', 'F', 'IT'),
(876, 'Wei Müller', 'F', 'UK'),
(877, 'David Marin', 'M', 'JP'),
(878, 'Sara Kim', 'M', 'UK'),
(879, 'James Sato', 'M', 'CN'),
(880, 'Wei Marin', 'M', 'CN'),
(881, 'Luca Rossi', 'F', 'CN'),
(882, 'Anna Conti', 'F', 'FR'),
(883, 'Nina Sato', 'F', 'ES'),
(884, 'James Zhang', 'F', 'FR'),
(885, 'Sofia Hernandez', 'M', 'US'),
(886, 'Alex Sato', 'F', 'ES'),
(887, 'Marta Anderson', 'F', 'CN'),
(888, 'Elena Zhang', 'F', 'IT'),
(889, 'Wei Lopez', 'F', 'JP'),
(890, 'Luca Rossi', 'F', 'US'),
(891, 'David Rossi', 'F', 'UK'),
(892, 'Pierre Bianchi', 'F', 'JP'),
(893, 'Ming Kobayashi', 'M', 'CN'),
(894, 'John Marin', 'F', 'CN'),
(895, 'Oliver Rossi', 'M', 'CN'),
(896, 'Emma Martin', 'M', 'CN'),
(897, 'Hiro Müller', 'M', 'CN'),
(898, 'Wei Johnson', 'F', 'CN'),
(899, 'Nina Sato', 'M', 'IT'),
(900, 'Pierre Smith', 'F', 'IT'),
(901, 'James Johnson', 'F', 'ES'),
(902, 'Alex Smith', 'F', 'IT'),
(903, 'Ming Garcia', 'M', 'JP'),
(904, 'Marco Lopez', 'F', 'JP'),
(905, 'David Johnson', 'M', 'UK'),
(906, 'Nina Anderson', 'F', 'FR'),
(907, 'Wei Müller', 'M', 'ES'),
(908, 'John Hernandez', 'F', 'JP'),
(909, 'Nina Zhang', 'F', 'CN'),
(910, 'Oliver Li', 'F', 'IT'),
(911, 'James Li', 'M', 'CN'),
(912, 'David Garcia', 'F', 'DE'),
(913, 'Pierre Sato', 'M', 'JP'),
(914, 'Wei Brown', 'M', 'JP'),
(915, 'Marco Brown', 'F', 'CN'),
(916, 'Alex Verdi', 'M', 'CN'),
(917, 'Pierre Müller', 'M', 'JP'),
(918, 'John Martin', 'M', 'JP'),
(919, 'Marta Smith', 'M', 'CN'),
(920, 'Alex Marin', 'M', 'DE'),
(921, 'Oliver Johnson', 'F', 'CN'),
(922, 'John Hernandez', 'F', 'CN'),
(923, 'Alex Hernandez', 'M', 'FR'),
(924, 'Hiro Rossi', 'M', 'JP'),
(925, 'Pierre Marin', 'F', 'US'),
(926, 'Ming Garcia', 'F', 'US'),
(927, 'Luca Martin', 'M', 'JP'),
(928, 'Anna Zhang', 'M', 'DE'),
(929, 'Elena Kim', 'M', 'US'),
(930, 'Sara Kim', 'M', 'US'),
(931, 'Luca Conti', 'M', 'ES'),
(932, 'David Rossi', 'F', 'US'),
(933, 'Elena Johnson', 'F', 'US'),
(934, 'Oliver Rossi', 'M', 'CN'),
(935, 'Sofia Kobayashi', 'M', 'FR'),
(936, 'Wei Sato', 'F', 'UK'),
(937, 'Oliver Dubois', 'F', 'DE'),
(938, 'Marco Sato', 'M', 'US'),
(939, 'Sofia Bianchi', 'F', 'ES'),
(940, 'David Bianchi', 'F', 'IT'),
(941, 'Elena Bianchi', 'F', 'UK'),
(942, 'Luca Martin', 'F', 'CN'),
(943, 'Alex Sato', 'F', 'ES'),
(944, 'Nina Rossi', 'M', 'US'),
(945, 'Emma Müller', 'F', 'DE'),
(946, 'Elena Zhang', 'F', 'CN'),
(947, 'Anna Smith', 'M', 'IT'),
(948, 'Yuki Dubois', 'F', 'UK'),
(949, 'Marta Marin', 'F', 'IT'),
(950, 'Alex Garcia', 'F', 'CN'),
(951, 'Yuki Garcia', 'F', 'UK'),
(952, 'Nina Anderson', 'F', 'IT'),
(953, 'Hiro Kobayashi', 'F', 'IT'),
(954, 'James Martin', 'F', 'US'),
(955, 'James Müller', 'M', 'FR'),
(956, 'Sara Anderson', 'F', 'CN'),
(957, 'John Smith', 'F', 'US'),
(958, 'Hiro Zhang', 'F', 'DE'),
(959, 'James Martin', 'M', 'JP'),
(960, 'Anna Garcia', 'F', 'US'),
(961, 'David Martin', 'F', 'US'),
(962, 'Yuki Lopez', 'F', 'JP'),
(963, 'Luca Martin', 'M', 'JP'),
(964, 'Sofia Verdi', 'F', 'US'),
(965, 'David Zhang', 'M', 'US'),
(966, 'Pierre Li', 'M', 'FR'),
(967, 'Hiro Johnson', 'F', 'FR'),
(968, 'Marco Rossi', 'F', 'CN'),
(969, 'Emma Kobayashi', 'F', 'FR'),
(970, 'Alex Hernandez', 'M', 'JP'),
(971, 'Hiro Sato', 'M', 'US'),
(972, 'Sofia Lopez', 'M', 'ES'),
(973, 'Wei Hernandez', 'F', 'US'),
(974, 'Oliver Sato', 'M', 'IT'),
(975, 'James Smith', 'M', 'US'),
(976, 'Elena Kim', 'M', 'IT'),
(977, 'Sara Sato', 'M', 'US'),
(978, 'Wei Rossi', 'M', 'JP'),
(979, 'Anna Brown', 'F', 'IT'),
(980, 'James Anderson', 'M', 'CN'),
(981, 'Giulia Johnson', 'F', 'FR'),
(982, 'Marta Smith', 'F', 'JP'),
(983, 'Marta Bianchi', 'M', 'US'),
(984, 'Marta Müller', 'F', 'JP'),
(985, 'Sofia Brown', 'F', 'IT'),
(986, 'Sofia Marin', 'M', 'US'),
(987, 'Ming Johnson', 'F', 'ES'),
(988, 'Ming Johnson', 'F', 'UK'),
(989, 'James Hernandez', 'M', 'JP'),
(990, 'Emma Dubois', 'F', 'UK'),
(991, 'Elena Johnson', 'M', 'JP'),
(992, 'Sara Martin', 'M', 'DE'),
(993, 'Sofia Lopez', 'M', 'US'),
(994, 'Hiro Müller', 'M', 'DE'),
(995, 'Wei Bianchi', 'M', 'IT'),
(996, 'Giulia Martin', 'M', 'US'),
(997, 'Elena Marin', 'F', 'US'),
(998, 'Pierre Anderson', 'F', 'US'),
(999, 'Alex Kim', 'F', 'US'),
(1000, 'Marta Lopez', 'F', 'JP');

INSERT INTO PRODOTTO (prodotto_id, codice, nome, prezzo, categoria_id, marchio_id, stagione_id) VALUES
(1, 'PRD0001', 'Gala Mirage', 1029.78, 10, 200, 2401),
(2, 'PRD0002', 'Lumina Zenith', 201.31, 40, 200, 2402),
(3, 'PRD0003', 'Luxe Édition', 535.71, 20, 300, 2402),
(4, 'PRD0004', 'Opulence Mirage', 724.07, 30, 300, 2502),
(5, 'PRD0005', 'Aurora Édition', 179.09, 50, 100, 2502),
(6, 'PRD0006', 'Aurora RX', 583.88, 20, 300, 2501),
(7, 'PRD0007', 'Stella Essence', 162.08, 50, 200, 2401),
(8, 'PRD0008', 'Vogue Nova', 232.38, 50, 100, 2501),
(9, 'PRD0009', 'Côte Elite', 234.43, 50, 100, 2502),
(10, 'PRD0010', 'Velour 2025', 170.4, 50, 200, 2501),
(11, 'PRD0011', 'Charme Zenith', 188.39, 50, 200, 2501),
(12, 'PRD0012', 'Éclat Essence', 885.96, 10, 200, 2402),
(13, 'PRD0013', 'Maison Essence', 500.66, 20, 100, 2401),
(14, 'PRD0014', 'Maison Chic', 849.35, 30, 100, 2501),
(15, 'PRD0015', 'Éclat Elite', 244.66, 50, 100, 2501),
(16, 'PRD0016', 'Prestige Nova', 424.79, 20, 100, 2501),
(17, 'PRD0017', 'Lumina RX', 155.59, 50, 200, 2502),
(18, 'PRD0018', 'Charme Édition', 213.36, 40, 300, 2401),
(19, 'PRD0019', 'Côte Édition', 858.64, 30, 100, 2501),
(20, 'PRD0020', 'Iconique Essence', 292.91, 40, 100, 2402),
(21, 'PRD0021', 'Côte Chic', 993.27, 10, 100, 2402),
(22, 'PRD0022', 'Opulence Essence', 571.23, 30, 200, 2401),
(23, 'PRD0023', 'Luxe 2025', 859.49, 10, 300, 2502),
(24, 'PRD0024', 'Velour Zenith', 540.02, 30, 200, 2501),
(25, 'PRD0025', 'Linea Verve', 223.85, 40, 100, 2501),
(26, 'PRD0026', 'Mirage 2025', 461.16, 20, 300, 2402),
(27, 'PRD0027', 'Velour Haute', 770.4, 30, 100, 2501),
(28, 'PRD0028', 'Côte Prime', 899.25, 30, 100, 2501),
(29, 'PRD0029', 'Elysium Prime', 251.57, 40, 100, 2402),
(30, 'PRD0030', 'Iconique Chic', 666.24, 30, 100, 2502),
(31, 'PRD0031', 'Gala Zenith', 880.23, 30, 200, 2402),
(32, 'PRD0032', 'Luxe Nova', 226.61, 40, 200, 2402),
(33, 'PRD0033', 'Lumina LX', 623.93, 20, 200, 2402),
(34, 'PRD0034', 'Opulence Prime', 595.82, 30, 100, 2501),
(35, 'PRD0035', 'Prestige Zenith', 1101.5, 10, 100, 2501),
(36, 'PRD0036', 'Vogue Mirage', 424.34, 20, 100, 2501),
(37, 'PRD0037', 'Elysium Zenith', 470.48, 20, 100, 2402),
(38, 'PRD0038', 'Iconique Prime', 800.23, 30, 300, 2401),
(39, 'PRD0039', 'Altamira Essence', 162.05, 50, 100, 2402),
(40, 'PRD0040', 'Vogue Haute', 259.81, 40, 100, 2502),
(41, 'PRD0041', 'Côte 2025', 171.1, 50, 300, 2502),
(42, 'PRD0042', 'Noire Zenith', 585.65, 30, 100, 2402),
(43, 'PRD0043', 'Altamira LX', 798.14, 30, 300, 2401),
(44, 'PRD0044', 'Iconique Verve', 235.98, 50, 100, 2401),
(45, 'PRD0045', 'Gala Elite', 510.59, 30, 100, 2502),
(46, 'PRD0046', 'Opulence LX', 892.61, 30, 100, 2402),
(47, 'PRD0047', 'Maison Haute', 504.93, 20, 100, 2402),
(48, 'PRD0048', 'Altamira Royale', 589.94, 30, 100, 2401),
(49, 'PRD0049', 'Prestige Essence', 525.06, 30, 100, 2402),
(50, 'PRD0050', 'Maison 2025', 924.84, 10, 200, 2402),
(51, 'PRD0051', 'Prestige 2025', 487.67, 20, 200, 2501),
(52, 'PRD0052', 'Stella Royale', 611.35, 30, 100, 2502),
(53, 'PRD0053', 'Iconique Zenith', 994.48, 10, 100, 2501),
(54, 'PRD0054', 'Altamira Zenith', 550.23, 20, 100, 2402),
(55, 'PRD0055', 'Linea Essence', 482.84, 20, 100, 2401),
(56, 'PRD0056', 'Côte Zenith', 912.67, 10, 200, 2502),
(57, 'PRD0057', 'Noire Verve', 212.33, 50, 200, 2501),
(58, 'PRD0058', 'Velour RX', 585.38, 20, 200, 2402),
(59, 'PRD0059', 'Altamira Chic', 663.5, 20, 200, 2501),
(60, 'PRD0060', 'Éclat Verve', 840.31, 10, 200, 2502),
(61, 'PRD0061', 'Luxe Elite', 614.23, 20, 100, 2502),
(62, 'PRD0062', 'Elysium Édition', 162.67, 50, 100, 2502),
(63, 'PRD0063', 'Charme Elite', 979.7, 10, 100, 2502),
(64, 'PRD0064', 'Iconique Édition', 552.76, 20, 300, 2502),
(65, 'PRD0065', 'Gala LX', 848.05, 10, 300, 2402),
(66, 'PRD0066', 'Linea LX', 811.62, 10, 200, 2502),
(67, 'PRD0067', 'Noire Mirage', 292.6, 40, 200, 2501),
(68, 'PRD0068', 'Velour Royale', 647.62, 20, 200, 2501),
(69, 'PRD0069', 'Stella Prime', 295.55, 40, 100, 2402),
(70, 'PRD0070', 'Prestige RX', 185.08, 50, 100, 2401),
(71, 'PRD0071', 'Aurora Haute', 183.5, 50, 100, 2501),
(72, 'PRD0072', 'Luxe Zenith', 631.37, 30, 200, 2402),
(73, 'PRD0073', 'Altamira RX', 537.29, 20, 100, 2502),
(74, 'PRD0074', 'Linea Édition', 225.35, 40, 300, 2501),
(75, 'PRD0075', 'Lumina Elite', 210.86, 40, 100, 2402),
(76, 'PRD0076', 'Lumina Essence', 922.94, 10, 300, 2401),
(77, 'PRD0077', 'Iconique 2025', 225.42, 40, 100, 2402),
(78, 'PRD0078', 'Stella Chic', 204.07, 40, 100, 2401),
(79, 'PRD0079', 'Altamira Nova', 921.85, 10, 100, 2402),
(80, 'PRD0080', 'Elysium Essence', 687.49, 20, 100, 2502),
(81, 'PRD0081', 'Luxe Prime', 181.46, 50, 100, 2402),
(82, 'PRD0082', 'Maison RX', 1142.31, 10, 100, 2401),
(83, 'PRD0083', 'Vogue Royale', 240.87, 50, 200, 2501),
(84, 'PRD0084', 'Mirage Nova', 152.57, 50, 100, 2502),
(85, 'PRD0085', 'Noire Haute', 207.72, 50, 200, 2501),
(86, 'PRD0086', 'Elysium Royale', 226.36, 40, 100, 2501),
(87, 'PRD0087', 'Stella RX', 987.18, 10, 100, 2402),
(88, 'PRD0088', 'Opulence Zenith', 185.11, 50, 100, 2402),
(89, 'PRD0089', 'Éclat Zenith', 214.96, 40, 100, 2401),
(90, 'PRD0090', 'Maison LX', 737.53, 30, 100, 2402),
(91, 'PRD0091', 'Mirage RX', 679.94, 20, 200, 2402),
(92, 'PRD0092', 'Soleil LX', 1161.44, 10, 200, 2501),
(93, 'PRD0093', 'Mirage Chic', 755.0, 30, 300, 2501),
(94, 'PRD0094', 'Soleil 2025', 438.14, 20, 300, 2502),
(95, 'PRD0095', 'Iconique Mirage', 206.6, 40, 100, 2502),
(96, 'PRD0096', 'Linea Zenith', 222.69, 40, 200, 2401),
(97, 'PRD0097', 'Luxe Mirage', 164.05, 50, 100, 2501),
(98, 'PRD0098', 'Soleil Édition', 721.7, 30, 300, 2501),
(99, 'PRD0099', 'Éclat RX', 577.81, 30, 100, 2402),
(100, 'PRD0100', 'Luxe Chic', 264.38, 40, 200, 2401);

USE CATALOG fashion_catalog;
USE SCHEMA fashion_synthetic_2;

CREATE OR REPLACE TABLE fashion_catalog.fashion_synthetic_2.dettaglio_scontrino_staging (
  scontrino_id STRING,
  numero_riga STRING,
  prodotto_id STRING,
  quantita STRING,
  prezzo_unitario_locale STRING
);

-- 2. Load CSV into the staging table
COPY INTO fashion_catalog.fashion_synthetic_2.dettaglio_scontrino_staging
FROM '/Volumes/fashion_catalog/fashion_synthetic_2/sources/DETTAGLIO_SCONTRINO.csv'
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true');

-- 3. Insert into the target table with explicit casting
INSERT INTO fashion_catalog.fashion_synthetic_2.dettaglio_scontrino
SELECT
  CAST(scontrino_id AS BIGINT),
  CAST(numero_riga AS INT),
  CAST(prodotto_id AS BIGINT),
  CAST(quantita AS INT),
  CAST(prezzo_unitario_locale AS DECIMAL(10,2))
FROM fashion_catalog.fashion_synthetic_2.dettaglio_scontrino_staging;


DROP TABLE fashion_catalog.fashion_synthetic_2.scontrino_staging;
-- 1. Create a staging table with all columns as STRING
CREATE OR REPLACE TABLE fashion_catalog.fashion_synthetic_2.scontrino_staging (
  scontrino_id STRING,
  cliente_id STRING,
  data_scontrino STRING,
  valuta_id STRING,
  punto_vendita_id STRING
);

-- 2. Load CSV into the staging table
COPY INTO fashion_catalog.fashion_synthetic_2.scontrino_staging
FROM '/Volumes/fashion_catalog/fashion_synthetic_2/sources/SCONTRINO.csv'
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true');

-- 3. Insert into the target table with explicit casting
INSERT INTO fashion_catalog.fashion_synthetic_2.scontrino
SELECT
  CAST(scontrino_id AS BIGINT),
  CAST(cliente_id AS BIGINT),
  CAST(data_scontrino AS DATE),
  CAST(valuta_id AS BIGINT),
 CAST(punto_vendita_id AS BIGINT)
FROM fashion_catalog.fashion_synthetic_2.scontrino_staging;

SELECT * FROM fashion_catalog.fashion_synthetic_2.scontrino_staging



-- 1. Create a staging table with all columns as STRING
CREATE OR REPLACE TABLE fashion_catalog.fashion_synthetic_2.budget_scontrino_staging (
  data STRING,
  punto_vendita_id STRING,
  valuta_id STRING,
  budget_vendite STRING
);

-- 2. Load CSV into the staging table
COPY INTO fashion_catalog.fashion_synthetic_2.budget_scontrino_staging
FROM '/Volumes/fashion_catalog/fashion_synthetic_2/sources/BUDGET_SCONTRINO.csv'
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true');

-- 3. Insert into the target table with explicit casting
INSERT INTO fashion_catalog.fashion_synthetic_2.budget_scontrino
SELECT
  CAST(data AS DATE),
  CAST(punto_vendita_id AS BIGINT),
  CAST(valuta_id AS BIGINT),
  CAST(budget_vendite AS decimal(12,2))
  FROM fashion_catalog.fashion_synthetic_2.budget_scontrino_staging;
